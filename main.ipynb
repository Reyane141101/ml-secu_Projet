# %%
import numpy as np
import pandas as pd
import openpyxl

# %%
dataframe22juin = pd.read_excel("22June2020 (1).xlsx","22June2020_B")
dataframe22juin_2 = pd.read_excel("22June2020 (1).xlsx","22June2020_A")
#dataframe29juin = pd.read_excel("29June2020 (1).xlsx","29June2020_B")
#dataframe29juin_2 = pd.read_excel("29June2020 (2).xlsx","29June2020_A")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/reyou/ml-secu/projet/SWaT.A7_June 2020/main.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/reyou/ml-secu/projet/SWaT.A7_June%202020/main.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> dataframe22juin = pd.read_excel("22June2020 (1).xlsx","22June2020_B")
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/reyou/ml-secu/projet/SWaT.A7_June%202020/main.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> dataframe22juin_2 = pd.read_excel("22June2020 (1).xlsx","22June2020_A")
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/reyou/ml-secu/projet/SWaT.A7_June%202020/main.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> dataframe29juin = pd.read_excel("29June2020 (1).xlsx","29June2020_B")
# ...

# %%
dataframe.head()
# Out:
#                   t_stamp  P1_STATE   LIT101.Pv  FIT101.Pv  MV101.Status  \
# 0 2020-06-22 10:00:00.000         3  695.284100        0.0             1
# 1 2020-06-22 10:00:01.000         3  695.127100        0.0             1
# 2 2020-06-22 10:00:02.005         3  694.930847        0.0             1
# 3 2020-06-22 10:00:03.010         3  694.930847        0.0             1
# 4 2020-06-22 10:00:04.015         3  694.852300        0.0             1
#
#    P101.Status  P102.Status  P2_STATE  FIT201.Pv  AIT201.Pv  ...  FIT601.Pv  \
# 0            1            1         2   0.000256  18.072288  ...   0.000256
# 1            1            1         2   0.000256  18.104332  ...   0.000256
# 2            1            1         2   0.000256  18.104332  ...   0.000256
# 3            1            1         2   0.000256  18.104332  ...   0.000256
# 4            1            1         2   0.000256  18.104332  ...   0.000256
#
# ...
